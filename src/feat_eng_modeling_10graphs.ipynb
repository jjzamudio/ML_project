# %%
for i in range(10):
    plt.figure(figsize=(20,10))
    plt.xlim(-2.5,2.5)
    plt.ylim(0,5)
    if i != 10:
        plt.scatter(X_test['px'],X_test['pz'],s=.05, c=probs[(probs >= 0.1* i)&(probs<0.1*(i+1))], alpha=0.2, cmap='Reds');
    else:
        plt.scatter(X_test['px'],X_test['pz'],s=.05, c=probs[(probs >= 0.1* i)&(probs<=0.1*(i+1))], alpha=0.2, cmap='Reds');
    plt.xlabel('Horizontal location',fontsize=16)
    plt.ylabel('Vertical location',fontsize=16)
    plt.tick_params(axis='both', which='major', labelsize=16)
    plt.show()
    #plt.legend(('Bad Pitch', 'Good Pitch'), loc='best', fontsize=16)
    #plt.savefig('predictions_RF.jpg')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-32-69e855035214> in <module>()
#      11     plt.ylabel('Vertical location',fontsize=16)
#      12     plt.tick_params(axis='both', which='major', labelsize=16)
# ---> 13     plt.show()
#      14     #plt.legend(('Bad Pitch', 'Good Pitch'), loc='best', fontsize=16)
#      15     #plt.savefig('predictions_RF.jpg')
#
# /Users/groupm/anaconda2/envs/py36/lib/python3.6/site-packages/matplotlib/pyplot.py in show(*args, **kw)
#     251     """
#     252     global _show
# --> 253     return _show(*args, **kw)
#     254
#     255
#
# /Users/groupm/anaconda2/envs/py36/lib/python3.6/site-packages/ipykernel/pylab/backend_inline.py in show(close, block)
#      34     try:
#      35         for figure_manager in Gcf.get_all_fig_managers():
# ---> 36             display(figure_manager.canvas.figure)
#      37     finally:
# ...

# %% [markdown]
# ## Save the probs vector

# %%
np.save('probs', probs)
#np.load('probs.npy')
